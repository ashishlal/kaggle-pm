# %%
import re
import numpy as np
import pandas as pd
import feather
import xgboost as xgb
import feather
from sklearn.base import BaseEstimator as be
from sklearn.base import TransformerMixin as tm
from sklearn.pipeline import Pipeline
from sklearn.pipeline import FeatureUnion
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.decomposition import TruncatedSVD
from sklearn.model_selection import train_test_split
from sklearn.metrics import log_loss

from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer

# %%
df_train = feather.read_dataframe('../cache/train_stage2_fe.feather')

# %%
df_train.shape
# Out:
# (3689, 3591)

# %%
df_train.head()
# Out:
#      Gene  ID                                               Text  \
# 0  FAM58A   0  Cyclin-dependent kinases (CDKs) regulate a var...
# 1     CBL   1   Abstract Background  Non-small cell lung canc...
# 2     CBL   2   Abstract Background  Non-small cell lung canc...
# 3     CBL   3  Recent evidence has demonstrated that acquired...
# 4     CBL   4  Oncogenic mutations in the monomeric Casitas B...
#
#               Variation                      GeneVar  Gene_Share  \
# 0  Truncating Mutations  FAM58A Truncating Mutations           1
# 1                 W802*                    CBL W802*           1
# 2                 Q249E                    CBL Q249E           1
# 3                 N454D                    CBL N454D           1
# 4                 L399V                    CBL L399V           1
#
#    Variation_Share  Gene_Variation_Share  GL  VL  ...    Gene_words  Text_len  \
# 0                1                     2   6  20  ...             1     39672
# 1                1                     2   3   5  ...             1     36691
# 2                1                     2   3   5  ...             1     36691
# 3                1                     2   3   5  ...             1     36238
# 4                1                     2   3   5  ...             1     41308
#
#    Text_words  Variation_lbl_enc  Variation_len  Variation_words  \
# 0        6105               3460             20                2
# 1        5783               3748              5                1
# 2        5783               2425              5                1
# 3        5625               2132              5                1
# 4        6248               1854              5                1
#
#    GeneVar_lbl_enc  GeneVar_len  GeneVar_words  Class
# 0             1654           27              3      1
# 1              941            9              2      2
# 2              933            9              2      2
# 3              929            9              2      3
# 4              927            9              2      4
#
# [5 rows x 3591 columns]

# %%
df_test = feather.read_dataframe('../cache/test_stage2_fe.feather')

# %%
df_test.shape
# Out:
# (986, 3590)

# %%
df_test.head()
# Out:
#      Gene  ID                                               Text  \
# 0   CHEK2   1  The incidence of breast cancer is increasing i...
# 1   AXIN2   2  An unselected series of 310 colorectal carcino...
# 2    WNT4   3  Mycosis fungoides and Sézary syndrome are prim...
# 3  SUCLA2   4   Regulated progression through the cell cycle ...
# 4    BRAF   5  Pilocytic astrocytoma (PA) is emerging as a tu...
#
#               Variation                     GeneVar  Gene_Share  \
# 0                 H371Y                 CHEK2 H371Y           1
# 1  Truncating Mutations  AXIN2 Truncating Mutations           1
# 2                 E216G                  WNT4 E216G           0
# 3                 G118R                SUCLA2 G118R           0
# 4             T599insTT              BRAF T599insTT           1
#
#    Variation_Share  Gene_Variation_Share  GL  VL      ...        Gene_len  \
# 0                1                     2   5   5      ...               5
# 1                1                     2   5  20      ...               5
# 2                1                     1   4   5      ...               4
# 3                1                     1   6   5      ...               6
# 4                0                     1   4   9      ...               4
#
#    Gene_words  Text_len  Text_words  Variation_lbl_enc  Variation_len  \
# 0           1     33403        4991               1379              5
# 1           1     66400       10348               3460             20
# 2           1     58544        8638                672              5
# 3           1     42023        6221               1038              5
# 4           1     22499        3280               3402              9
#
#    Variation_words  GeneVar_lbl_enc  GeneVar_len  GeneVar_words
# 0                1             1080           11              2
# 1                2              286           26              3
# 2                1             4287           10              2
# 3                1             3841           12              2
# 4                1              430           14              2
#
# [5 rows x 3590 columns]

# %%
pid = df_test.ID

# %%
########################################
## process texts in datasets
########################################


# The function "text_to_wordlist" is from
# https://www.kaggle.com/currie32/quora-question-pairs/the-importance-of-cleaning-text
def text_to_wordlist(text, remove_stopwords=True, stem_words=True):
    # Clean the text, with the option to remove stopwords and to stem words.
    
    # Convert words to lower case and split them
    text = text.lower().split()

    my_stopwords = [
        "fig", "figure", "et", "al", "table",
        "data", "analysis", "analyze", "study",
        "method", "result", "conclusion", "author",
        "find", "found", "show", "perform",
        "demonstrate", "evaluate", "discuss"
    ]
    
    # Optionally, remove stop words
    if remove_stopwords:
        stops = set(stopwords.words("english"))
        text = [w for w in text if not w in stops]
        text = [w for w in text if not w in my_stopwords]
    
    text = " ".join(text)

    # Clean the text
    text = re.sub(r"[^A-Za-z0-9^,!.\/'+-=]", " ", text)
    text = re.sub(r"what's", "what is ", text)
    text = re.sub(r"\'s", " ", text)
    text = re.sub(r"\'ve", " have ", text)
    text = re.sub(r"can't", "cannot ", text)
    text = re.sub(r"n't", " not ", text)
    text = re.sub(r"i'm", "i am ", text)
    text = re.sub(r"\'re", " are ", text)
    text = re.sub(r"\'d", " would ", text)
    text = re.sub(r"\'ll", " will ", text)
    text = re.sub(r",", " ", text)
    text = re.sub(r"\.", " ", text)
    text = re.sub(r"!", " ! ", text)
    text = re.sub(r"\/", " ", text)
    text = re.sub(r"\^", " ^ ", text)
    text = re.sub(r"\+", " + ", text)
    text = re.sub(r"\-", " - ", text)
    text = re.sub(r"\=", " = ", text)
    text = re.sub(r"'", " ", text)
    text = re.sub(r"(\d+)(k)", r"\g<1>000", text)
    text = re.sub(r":", " : ", text)
    text = re.sub(r" e g ", " eg ", text)
    text = re.sub(r" b g ", " bg ", text)
    text = re.sub(r" u s ", " american ", text)
    text = re.sub(r"\0s", "0", text)
    text = re.sub(r" 9 11 ", "911", text)
    text = re.sub(r"e - mail", "email", text)
    text = re.sub(r"j k", "jk", text)
    text = re.sub(r"\s{2,}", " ", text)
    
    # Optionally, shorten words to their stems
    if stem_words:
        text = text.split()
        stemmer = SnowballStemmer('english')
        stemmed_words = [stemmer.stem(word) for word in text]
        text = " ".join(stemmed_words)
    
    # Return a list of words
    return(text)

# %%
class cust_regression_vals(be, tm):
    def fit(self, x, y=None):
        return self
    def transform(self, x):
        x = x.drop(['Gene', 'Variation', 'ID','Text', 'GeneVar'],axis=1).values
        return x

class cust_txt_col(be, tm):
    def __init__(self, key):
        self.key = key
    def fit(self, x, y=None):
        return self
    def transform(self, x):
        return x[self.key].apply(str)

# %%
fp = Pipeline([
    ('union', FeatureUnion(
        n_jobs = -1,
        transformer_list = [
            ('standard', cust_regression_vals()),
            ('pi1', Pipeline([('Gene', cust_txt_col('Gene')), 
                                       ('count_Gene', CountVectorizer(analyzer=u'char',ngram_range=(1, 3))), 
                                       ('tsvd1', TruncatedSVD(n_components=20, n_iter=25, random_state=12))])),
            ('pi2', Pipeline([('Variation', cust_txt_col('Variation')), 
                                       ('count_Variation', CountVectorizer(analyzer=u'char',ngram_range=(1, 3))), 
                                       ('tsvd2', TruncatedSVD(n_components=20, n_iter=25, random_state=12))])),
            ('pi3', Pipeline([('GeneVar', cust_txt_col('GeneVar')), 
                                       ('count_GeneVar', CountVectorizer(analyzer=u'char', ngram_range=(1, 3))), 
                                       ('tsvd2', TruncatedSVD(n_components=20, n_iter=25, 
                                                                            random_state=12))])),
            ('pi4',Pipeline([('Text', cust_txt_col('Text')), 
                                       ('hv', HashingVectorizer(decode_error='ignore', 
                                                                                        n_features=2 ** 16,
                                                                                        non_negative=True, 
                                                                                        ngram_range=(1, 5))),
                                       ('tfidf_Text', TfidfTransformer()), 
                                       ('tsvd3', TruncatedSVD(n_components=300, n_iter=25, 
                                                                            random_state=12))]))

        
        ])
    )])

# %%
df_train['Text'] = [text_to_wordlist(w) for w in df_train['Text'].values]

# %%
df_test['Text'] = [text_to_wordlist(w) for w in df_test['Text'].values]

# %%
df_train.head()
# Out:
#      Gene  ID                                               Text  \
# 0  FAM58A   0  cyclin - depend kinas cdks regul varieti funda...
# 1     CBL   1  abstract background non - small cell lung canc...
# 2     CBL   2  abstract background non - small cell lung canc...
# 3     CBL   3  recent evid demonstr acquir uniparent disomi a...
# 4     CBL   4  oncogen mutat monomer casita b - lineag lympho...
#
#               Variation                      GeneVar  Gene_Share  \
# 0  Truncating Mutations  FAM58A Truncating Mutations           1
# 1                 W802*                    CBL W802*           1
# 2                 Q249E                    CBL Q249E           1
# 3                 N454D                    CBL N454D           1
# 4                 L399V                    CBL L399V           1
#
#    Variation_Share  Gene_Variation_Share  GL  VL  ...    Gene_words  Text_len  \
# 0                1                     2   6  20  ...             1     39672
# 1                1                     2   3   5  ...             1     36691
# 2                1                     2   3   5  ...             1     36691
# 3                1                     2   3   5  ...             1     36238
# 4                1                     2   3   5  ...             1     41308
#
#    Text_words  Variation_lbl_enc  Variation_len  Variation_words  \
# 0        6105               3460             20                2
# 1        5783               3748              5                1
# 2        5783               2425              5                1
# 3        5625               2132              5                1
# 4        6248               1854              5                1
#
#    GeneVar_lbl_enc  GeneVar_len  GeneVar_words  Class
# 0             1654           27              3      1
# 1              941            9              2      2
# 2              933            9              2      2
# 3              929            9              2      3
# 4              927            9              2      4
#
# [5 rows x 3591 columns]

# %%
y = df_train['Class'].values

# %%
tr = df_train
te = df_test

# %%
# y = tr['Class'].values

# %%
set(te.columns) - set(tr.columns)
# Out:
# set()

# %%
df_train = df_train.drop('Class',axis=1)

# %%
# df_train = df_train.drop('ID', axis=1)
# df_test = df_test.drop('ID', axis=1)

# %%
# df_train = tr

# %%
df_train = fp.fit_transform(df_train)
print (df_train.shape)
# Out:
# /home/watts/anaconda2/envs/aind-dog/lib/python3.6/site-packages/sklearn/feature_extraction/hashing.py:94: DeprecationWarning: the option non_negative=True has been deprecated in 0.19 and will be removed in version 0.21.
#   " in version 0.21.", DeprecationWarning)
# /home/watts/anaconda2/envs/aind-dog/lib/python3.6/site-packages/sklearn/feature_extraction/hashing.py:94: DeprecationWarning: the option non_negative=True has been deprecated in 0.19 and will be removed in version 0.21.
#   " in version 0.21.", DeprecationWarning)
# (3689, 3945)

# %%
df_test = fp.fit_transform(df_test)
print (df_test.shape)
# Out:
# /home/watts/anaconda2/envs/aind-dog/lib/python3.6/site-packages/sklearn/feature_extraction/hashing.py:94: DeprecationWarning: the option non_negative=True has been deprecated in 0.19 and will be removed in version 0.21.
#   " in version 0.21.", DeprecationWarning)
# /home/watts/anaconda2/envs/aind-dog/lib/python3.6/site-packages/sklearn/feature_extraction/hashing.py:94: DeprecationWarning: the option non_negative=True has been deprecated in 0.19 and will be removed in version 0.21.
#   " in version 0.21.", DeprecationWarning)
# (986, 3945)

# %%
y = y - 1 #fix for zero bound array

# %%
 

denom = 0
fold = 10 
for i in range(fold):
    params = {
        'eta': 0.03333,
        'max_depth': 6,
        'subsample' : 0.8,
        'colsample_bytree':0.8,
        'objective': 'multi:softprob',
        'eval_metric': 'mlogloss',
        'num_class': 9,
        'seed': i,
        'silent': True
    }
    x1, x2, y1, y2 = train_test_split(df_train, y, test_size=0.2, random_state=i)
    watchlist = [(xgb.DMatrix(x1, y1), 'train'), (xgb.DMatrix(x2, y2), 'valid')]
    model = xgb.train(params, xgb.DMatrix(x1, y1), 1000,  watchlist, verbose_eval=50, early_stopping_rounds=100)
    score1 = log_loss(y2, model.predict(xgb.DMatrix(x2), 
                                                ntree_limit=model.best_ntree_limit), labels = list(range(9)))
    print(score1)
    #if score < 0.9:
    if denom != 0:
        pred = model.predict(xgb.DMatrix(df_test), ntree_limit=model.best_ntree_limit+80)
        preds += pred
    else:
        pred = model.predict(xgb.DMatrix(df_test), ntree_limit=model.best_ntree_limit+80)
        preds = pred.copy()
    denom += 1
    submission = pd.DataFrame(pred, columns=['class'+str(c+1) for c in range(9)])
    submission['ID'] = pid
    submission.to_csv('../submissions/submission1_2_2_xgb_fold_'  + str(i) + '.csv', index=False)
# Out:
# [0]	train-mlogloss:2.12645	valid-mlogloss:2.14067
# Multiple eval metrics have been passed: 'valid-mlogloss' will be used for early stopping.
#
# Will train until valid-mlogloss hasn't improved in 100 rounds.
# [50]	train-mlogloss:0.814166	valid-mlogloss:1.15291
# [100]	train-mlogloss:0.452439	valid-mlogloss:0.960481
# [150]	train-mlogloss:0.280237	valid-mlogloss:0.901279
# [200]	train-mlogloss:0.181032	valid-mlogloss:0.890509
# [250]	train-mlogloss:0.121059	valid-mlogloss:0.894627
# Stopping. Best iteration:
# [184]	train-mlogloss:0.208369	valid-mlogloss:0.890166
#
# 0.89016613473
# [0]	train-mlogloss:2.12807	valid-mlogloss:2.13738
# Multiple eval metrics have been passed: 'valid-mlogloss' will be used for early stopping.
#
# Will train until valid-mlogloss hasn't improved in 100 rounds.
# [50]	train-mlogloss:0.812295	valid-mlogloss:1.09682
# [100]	train-mlogloss:0.455408	valid-mlogloss:0.883845
# [150]	train-mlogloss:0.284691	valid-mlogloss:0.814417
# [200]	train-mlogloss:0.185225	valid-mlogloss:0.795225
# [250]	train-mlogloss:0.124581	valid-mlogloss:0.794328
# [300]	train-mlogloss:0.087182	valid-mlogloss:0.799681
# Stopping. Best iteration:
# [236]	train-mlogloss:0.138526	valid-mlogloss:0.793647
#
# 0.793647106212
# [0]	train-mlogloss:2.12691	valid-mlogloss:2.13928
# Multiple eval metrics have been passed: 'valid-mlogloss' will be used for early stopping.
#
# Will train until valid-mlogloss hasn't improved in 100 rounds.
# [50]	train-mlogloss:0.81434	valid-mlogloss:1.14012
# [100]	train-mlogloss:0.451537	valid-mlogloss:0.944249
# [150]	train-mlogloss:0.280812	valid-mlogloss:0.880724
# [200]	train-mlogloss:0.182121	valid-mlogloss:0.860098
# [250]	train-mlogloss:0.122214	valid-mlogloss:0.859354
# [300]	train-mlogloss:0.084737	valid-mlogloss:0.862957
# Stopping. Best iteration:
# [223]	train-mlogloss:0.151453	valid-mlogloss:0.85685
#
# 0.856850089091
# [0]	train-mlogloss:2.13055	valid-mlogloss:2.13438
# Multiple eval metrics have been passed: 'valid-mlogloss' will be used for early stopping.
#
# Will train until valid-mlogloss hasn't improved in 100 rounds.
# [50]	train-mlogloss:0.823035	valid-mlogloss:1.07782
# [100]	train-mlogloss:0.465783	valid-mlogloss:0.864756
# [150]	train-mlogloss:0.294747	valid-mlogloss:0.799861
# [200]	train-mlogloss:0.193565	valid-mlogloss:0.778244
# [250]	train-mlogloss:0.13067	valid-mlogloss:0.773339
# [300]	train-mlogloss:0.091549	valid-mlogloss:0.774046
# [350]	train-mlogloss:0.066022	valid-mlogloss:0.781594
# Stopping. Best iteration:
# [275]	train-mlogloss:0.10904	valid-mlogloss:0.771858
#
# 0.771858256155
# [0]	train-mlogloss:2.12958	valid-mlogloss:2.13552
# Multiple eval metrics have been passed: 'valid-mlogloss' will be used for early stopping.
#
# Will train until valid-mlogloss hasn't improved in 100 rounds.
# [50]	train-mlogloss:0.819604	valid-mlogloss:1.09371
# [100]	train-mlogloss:0.463559	valid-mlogloss:0.885378
# [150]	train-mlogloss:0.288906	valid-mlogloss:0.82318
# [200]	train-mlogloss:0.188747	valid-mlogloss:0.804076
# [250]	train-mlogloss:0.126927	valid-mlogloss:0.804215
# [300]	train-mlogloss:0.088029	valid-mlogloss:0.815468
# Stopping. Best iteration:
# [227]	train-mlogloss:0.151834	valid-mlogloss:0.802208
#
# 0.802208080539
# [0]	train-mlogloss:2.12954	valid-mlogloss:2.14136
# Multiple eval metrics have been passed: 'valid-mlogloss' will be used for early stopping.
#
# Will train until valid-mlogloss hasn't improved in 100 rounds.
# [50]	train-mlogloss:0.814777	valid-mlogloss:1.17058
# [100]	train-mlogloss:0.449793	valid-mlogloss:0.985543
# [150]	train-mlogloss:0.278362	valid-mlogloss:0.936378
# [200]	train-mlogloss:0.17971	valid-mlogloss:0.930318
# [250]	train-mlogloss:0.12036	valid-mlogloss:0.939692
# Stopping. Best iteration:
# [189]	train-mlogloss:0.197091	valid-mlogloss:0.928109
#
# 0.928108738172
# [0]	train-mlogloss:2.13008	valid-mlogloss:2.13801
# Multiple eval metrics have been passed: 'valid-mlogloss' will be used for early stopping.
#
# Will train until valid-mlogloss hasn't improved in 100 rounds.
# [50]	train-mlogloss:0.821862	valid-mlogloss:1.12565
# [100]	train-mlogloss:0.462003	valid-mlogloss:0.924745
# [150]	train-mlogloss:0.286225	valid-mlogloss:0.865343
# [200]	train-mlogloss:0.184926	valid-mlogloss:0.84825
# [250]	train-mlogloss:0.123353	valid-mlogloss:0.850687
# [300]	train-mlogloss:0.085782	valid-mlogloss:0.858455
# Stopping. Best iteration:
# [212]	train-mlogloss:0.166921	valid-mlogloss:0.84696
#
# 0.846960342733
# [0]	train-mlogloss:2.12698	valid-mlogloss:2.1374
# Multiple eval metrics have been passed: 'valid-mlogloss' will be used for early stopping.
#
# Will train until valid-mlogloss hasn't improved in 100 rounds.
# [50]	train-mlogloss:0.817613	valid-mlogloss:1.14546
# [100]	train-mlogloss:0.45733	valid-mlogloss:0.950174
# [150]	train-mlogloss:0.284602	valid-mlogloss:0.888061
# [200]	train-mlogloss:0.183363	valid-mlogloss:0.86695
# [250]	train-mlogloss:0.124089	valid-mlogloss:0.865585
# [300]	train-mlogloss:0.085722	valid-mlogloss:0.877317
# Stopping. Best iteration:
# [233]	train-mlogloss:0.140778	valid-mlogloss:0.864442
#
# 0.864442194685
# [0]	train-mlogloss:2.12809	valid-mlogloss:2.13646
# Multiple eval metrics have been passed: 'valid-mlogloss' will be used for early stopping.
#
# Will train until valid-mlogloss hasn't improved in 100 rounds.
# [50]	train-mlogloss:0.825223	valid-mlogloss:1.12399
# [100]	train-mlogloss:0.459621	valid-mlogloss:0.920612
# [150]	train-mlogloss:0.286899	valid-mlogloss:0.865689
# [200]	train-mlogloss:0.185906	valid-mlogloss:0.854709
# [250]	train-mlogloss:0.125923	valid-mlogloss:0.856262
# [300]	train-mlogloss:0.087937	valid-mlogloss:0.865832
# Stopping. Best iteration:
# [218]	train-mlogloss:0.161304	valid-mlogloss:0.852712
#
# 0.852711635969
# [0]	train-mlogloss:2.12814	valid-mlogloss:2.14064
# Multiple eval metrics have been passed: 'valid-mlogloss' will be used for early stopping.
#
# Will train until valid-mlogloss hasn't improved in 100 rounds.
# [50]	train-mlogloss:0.807037	valid-mlogloss:1.18013
# [100]	train-mlogloss:0.44539	valid-mlogloss:0.997991
# [150]	train-mlogloss:0.27845	valid-mlogloss:0.955579
# [200]	train-mlogloss:0.180372	valid-mlogloss:0.950212
# [250]	train-mlogloss:0.12065	valid-mlogloss:0.957606
# Stopping. Best iteration:
# [183]	train-mlogloss:0.208296	valid-mlogloss:0.949414
#
# 0.94941358294

# %%
submission = pd.DataFrame(preds/denom, columns=['class'+str(c+1) for c in range(9)])
submission['ID'] = pid
submission.to_csv('../submissions/submission_all_2_2_xgb.csv', index=False)

# %%
len(y)
# Out:
# 3689

# %%
y
# Out:
# array([0, 1, 1, ..., 5, 3, 0])

# %%
y_pseudo = preds/denom

# %%
len(y_pseudo)
# Out:
# 986

# %%
y_pseudo
# Out:
# array([[ 0.36826095,  0.03778919,  0.02021655, ...,  0.03634918,
#          0.00809619,  0.00777789],
#        [ 0.86791885,  0.02721421,  0.00515629, ...,  0.02514629,
#          0.0041679 ,  0.0027892 ],
#        [ 0.07454448,  0.09149207,  0.01409115, ...,  0.35999787,
#          0.01568171,  0.01071824],
#        ...,
#        [ 0.16088469,  0.2002444 ,  0.06238246, ...,  0.09231327,
#          0.01163716,  0.00876702],
#        [ 0.09382014,  0.17505959,  0.01044971, ...,  0.25275773,
#          0.0062432 ,  0.00909903],
#        [ 0.27108249,  0.24305496,  0.01503516, ...,  0.14290585,
#          0.01782902,  0.00903406]], dtype=float32)

# %%
df_preds = pd.read_csv('../submissions/submission_all_2_2_xgb.csv',index_col=False)
df_preds = df_preds.drop('ID', axis=1)
df_preds['class'] = df_preds.idxmax(axis=1)
df_preds['class'] = df_preds['class'].str[-1].astype(int)
df_preds['class'] = df_preds['class'] -1
df_preds = df_preds.drop(['class1','class2','class3','class4','class5','class6',
                          'class7','class8','class9'],axis=1)
y_pseudo = df_preds['class'].values

# %%
Y = np.concatenate((y, y_pseudo), axis=0)

# %%
X = np.concatenate((df_train, df_test), axis=0)

# %%
denom = 0
fold = 10 #Change to 5, 1 for Kaggle Limits
for i in range(fold):
    params = {
        'eta': 0.03333,
        'max_depth': 6,
        'subsample' : 0.8,
        'colsample_bytree':0.8,
        'objective': 'multi:softprob',
        'eval_metric': 'mlogloss',
        'num_class': 9,
        'seed': i,
        'silent': True,
        'tree_method': 'gpu_hist'
    }
    x1, x2, y1, y2 = train_test_split(X, Y, test_size=0.2, random_state=i)
    watchlist = [(xgb.DMatrix(x1, y1), 'train'), (xgb.DMatrix(x2, y2), 'valid')]
    model = xgb.train(params, xgb.DMatrix(x1, y1), 1000,  watchlist, verbose_eval=50, early_stopping_rounds=100)
    score1 = log_loss(y2, model.predict(xgb.DMatrix(x2), 
                                                ntree_limit=model.best_ntree_limit), labels = list(range(9)))
    print(score1)
    #if score < 0.9:
    if denom != 0:
        pred = model.predict(xgb.DMatrix(df_test), ntree_limit=model.best_ntree_limit+80)
        preds += pred
    else:
        pred = model.predict(xgb.DMatrix(df_test), ntree_limit=model.best_ntree_limit+80)
        preds = pred.copy()
    denom += 1
    submission = pd.DataFrame(pred, columns=['class'+str(c+1) for c in range(9)])
    submission['ID'] = pid
    submission.to_csv('../submissions/submission_2_2_2_xgb_fold_'  + str(i) + '.csv', index=False)
# Out:
# [0]	train-mlogloss:2.12674	valid-mlogloss:2.13724
# Multiple eval metrics have been passed: 'valid-mlogloss' will be used for early stopping.
#
# Will train until valid-mlogloss hasn't improved in 100 rounds.
# [50]	train-mlogloss:0.829239	valid-mlogloss:1.10881
# [100]	train-mlogloss:0.462287	valid-mlogloss:0.891414
# [150]	train-mlogloss:0.295943	valid-mlogloss:0.816415
# [200]	train-mlogloss:0.195164	valid-mlogloss:0.789973
# [250]	train-mlogloss:0.13397	valid-mlogloss:0.782631
# [300]	train-mlogloss:0.095242	valid-mlogloss:0.785123
# [350]	train-mlogloss:0.069508	valid-mlogloss:0.79311
# Stopping. Best iteration:
# [251]	train-mlogloss:0.133008	valid-mlogloss:0.782186
#
# 0.782186010988
# [0]	train-mlogloss:2.12718	valid-mlogloss:2.13406
# Multiple eval metrics have been passed: 'valid-mlogloss' will be used for early stopping.
#
# Will train until valid-mlogloss hasn't improved in 100 rounds.
# [50]	train-mlogloss:0.823479	valid-mlogloss:1.07715
# [100]	train-mlogloss:0.458378	valid-mlogloss:0.854327
# [150]	train-mlogloss:0.293257	valid-mlogloss:0.783848
# [200]	train-mlogloss:0.196165	valid-mlogloss:0.75978
# [250]	train-mlogloss:0.134699	valid-mlogloss:0.75509
# [300]	train-mlogloss:0.094797	valid-mlogloss:0.754806
# [350]	train-mlogloss:0.069416	valid-mlogloss:0.760851
# Stopping. Best iteration:
# [280]	train-mlogloss:0.108731	valid-mlogloss:0.752865
#
# 0.75286521476
# [0]	train-mlogloss:2.13099	valid-mlogloss:2.13616
# Multiple eval metrics have been passed: 'valid-mlogloss' will be used for early stopping.
#
# Will train until valid-mlogloss hasn't improved in 100 rounds.
# [50]	train-mlogloss:0.823687	valid-mlogloss:1.08946
# [100]	train-mlogloss:0.458519	valid-mlogloss:0.883642
# [150]	train-mlogloss:0.291981	valid-mlogloss:0.819864
# [200]	train-mlogloss:0.194471	valid-mlogloss:0.801164
# [250]	train-mlogloss:0.1338	valid-mlogloss:0.799639
# [300]	train-mlogloss:0.094673	valid-mlogloss:0.803281
# Stopping. Best iteration:
# [236]	train-mlogloss:0.148321	valid-mlogloss:0.799347
#
# 0.799346530252
# [0]	train-mlogloss:2.12759	valid-mlogloss:2.1353
# Multiple eval metrics have been passed: 'valid-mlogloss' will be used for early stopping.
#
# Will train until valid-mlogloss hasn't improved in 100 rounds.
# [50]	train-mlogloss:0.823201	valid-mlogloss:1.09971
# [100]	train-mlogloss:0.459853	valid-mlogloss:0.874333
# [150]	train-mlogloss:0.291745	valid-mlogloss:0.797077
# [200]	train-mlogloss:0.192668	valid-mlogloss:0.769211
# [250]	train-mlogloss:0.132233	valid-mlogloss:0.758721
# [300]	train-mlogloss:0.093769	valid-mlogloss:0.757353
# [350]	train-mlogloss:0.068236	valid-mlogloss:0.761804
# [400]	train-mlogloss:0.051147	valid-mlogloss:0.76725
# Stopping. Best iteration:
# [307]	train-mlogloss:0.089665	valid-mlogloss:0.756826
#
# 0.756825633029
# [0]	train-mlogloss:2.1255	valid-mlogloss:2.13597
# Multiple eval metrics have been passed: 'valid-mlogloss' will be used for early stopping.
#
# Will train until valid-mlogloss hasn't improved in 100 rounds.
# [50]	train-mlogloss:0.822055	valid-mlogloss:1.08793
# [100]	train-mlogloss:0.460309	valid-mlogloss:0.867701
# [150]	train-mlogloss:0.291064	valid-mlogloss:0.798548
# [200]	train-mlogloss:0.192388	valid-mlogloss:0.77356
# [250]	train-mlogloss:0.13303	valid-mlogloss:0.767519
# [300]	train-mlogloss:0.093725	valid-mlogloss:0.770587
# [350]	train-mlogloss:0.068174	valid-mlogloss:0.776241
# Stopping. Best iteration:
# [254]	train-mlogloss:0.129362	valid-mlogloss:0.76734
#
# 0.76733954353
# [0]	train-mlogloss:2.12556	valid-mlogloss:2.13242
# Multiple eval metrics have been passed: 'valid-mlogloss' will be used for early stopping.
#
# Will train until valid-mlogloss hasn't improved in 100 rounds.
# [50]	train-mlogloss:0.820122	valid-mlogloss:1.1021
# [100]	train-mlogloss:0.459778	valid-mlogloss:0.899895
# [150]	train-mlogloss:0.292396	valid-mlogloss:0.842182
# [200]	train-mlogloss:0.192139	valid-mlogloss:0.833124
# [250]	train-mlogloss:0.131771	valid-mlogloss:0.837777
# [300]	train-mlogloss:0.092457	valid-mlogloss:0.850151
# Stopping. Best iteration:
# [206]	train-mlogloss:0.183294	valid-mlogloss:0.833117
#
# 0.833116726454
# [0]	train-mlogloss:2.12552	valid-mlogloss:2.13654
# Multiple eval metrics have been passed: 'valid-mlogloss' will be used for early stopping.
#
# Will train until valid-mlogloss hasn't improved in 100 rounds.
# [50]	train-mlogloss:0.817195	valid-mlogloss:1.11005
# [100]	train-mlogloss:0.458567	valid-mlogloss:0.902517
# [150]	train-mlogloss:0.289126	valid-mlogloss:0.839281
# [200]	train-mlogloss:0.190542	valid-mlogloss:0.819295
# [250]	train-mlogloss:0.130984	valid-mlogloss:0.819058
# [300]	train-mlogloss:0.091775	valid-mlogloss:0.824756
# Stopping. Best iteration:
# [228]	train-mlogloss:0.153505	valid-mlogloss:0.817249
#
# 0.817248632126
# [0]	train-mlogloss:2.12568	valid-mlogloss:2.13491
# Multiple eval metrics have been passed: 'valid-mlogloss' will be used for early stopping.
#
# Will train until valid-mlogloss hasn't improved in 100 rounds.
# [50]	train-mlogloss:0.818417	valid-mlogloss:1.09846
# [100]	train-mlogloss:0.457859	valid-mlogloss:0.888748
# [150]	train-mlogloss:0.28841	valid-mlogloss:0.821685
# [200]	train-mlogloss:0.189447	valid-mlogloss:0.79722
# [250]	train-mlogloss:0.129628	valid-mlogloss:0.79103
# [300]	train-mlogloss:0.091189	valid-mlogloss:0.79298
# Stopping. Best iteration:
# [237]	train-mlogloss:0.142487	valid-mlogloss:0.790566
#
# 0.790565825173
# [0]	train-mlogloss:2.12902	valid-mlogloss:2.13624
# Multiple eval metrics have been passed: 'valid-mlogloss' will be used for early stopping.
#
# Will train until valid-mlogloss hasn't improved in 100 rounds.
# [50]	train-mlogloss:0.831187	valid-mlogloss:1.0699
# [100]	train-mlogloss:0.463643	valid-mlogloss:0.837895
# [150]	train-mlogloss:0.2967	valid-mlogloss:0.761154
# [200]	train-mlogloss:0.195739	valid-mlogloss:0.732385
# [250]	train-mlogloss:0.134921	valid-mlogloss:0.720179
# [300]	train-mlogloss:0.096335	valid-mlogloss:0.719189
# [350]	train-mlogloss:0.070674	valid-mlogloss:0.722057
# Stopping. Best iteration:
# [289]	train-mlogloss:0.103715	valid-mlogloss:0.718189
#
# 0.718188509762
# [0]	train-mlogloss:2.12692	valid-mlogloss:2.13501
# Multiple eval metrics have been passed: 'valid-mlogloss' will be used for early stopping.
#
# Will train until valid-mlogloss hasn't improved in 100 rounds.
# [50]	train-mlogloss:0.8264	valid-mlogloss:1.08499
# [100]	train-mlogloss:0.462925	valid-mlogloss:0.857333
# [150]	train-mlogloss:0.292505	valid-mlogloss:0.787343
# [200]	train-mlogloss:0.19411	valid-mlogloss:0.764941
# [250]	train-mlogloss:0.132045	valid-mlogloss:0.756726
# [300]	train-mlogloss:0.093705	valid-mlogloss:0.757434
# [350]	train-mlogloss:0.068323	valid-mlogloss:0.764917
# Stopping. Best iteration:
# [266]	train-mlogloss:0.117981	valid-mlogloss:0.755257
#
# 0.755257426209

# %%
submission = pd.DataFrame(preds/denom, columns=['class'+str(c+1) for c in range(9)])
submission['ID'] = pid
submission.to_csv('../submissions/submission_all_2_2_2_xgb.csv', index=False)

# %%
# score 3.09512 on public leader board
